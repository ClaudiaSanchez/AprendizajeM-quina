# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np
import pandas

# %%
df = pandas.read_csv('adult.data.csv')
#df.columns # columnas
#df.values  # datos
print(df.values.shape)
print(df)
# Out:
# (32560, 15)
#        39          State-gov   77516    Bachelors   13        Never-married  \
# 0      50   Self-emp-not-inc   83311    Bachelors   13   Married-civ-spouse
# 1      38            Private  215646      HS-grad    9             Divorced
# 2      53            Private  234721         11th    7   Married-civ-spouse
# 3      28            Private  338409    Bachelors   13   Married-civ-spouse
# 4      37            Private  284582      Masters   14   Married-civ-spouse
# ...    ..                ...     ...          ...  ...                  ...
# 32555  27            Private  257302   Assoc-acdm   12   Married-civ-spouse
# 32556  40            Private  154374      HS-grad    9   Married-civ-spouse
# 32557  58            Private  151910      HS-grad    9              Widowed
# 32558  22            Private  201490      HS-grad    9        Never-married
# 32559  52       Self-emp-inc  287927      HS-grad    9   Married-civ-spouse
#
# ...

# %%
feature = df.values[:,-2]
feature_values, feature_counts = np.unique(feature,return_counts=True)
for i in range(len(feature_values)):
    print(feature_values[i],feature_counts[i])
# Out:
#  ? 583
#  Cambodia 19
#  Canada 121
#  China 75
#  Columbia 59
#  Cuba 95
#  Dominican-Republic 70
#  Ecuador 28
#  El-Salvador 106
#  England 90
#  France 29
#  Germany 137
#  Greece 29
#  Guatemala 64
#  Haiti 44
#  Holand-Netherlands 1
#  Honduras 13
#  Hong 20
#  Hungary 13
#  India 100
#  Iran 43
#  Ireland 24
#  Italy 73
#  Jamaica 81
#  Japan 62
#  Laos 18
#  Mexico 643
#  Nicaragua 34
#  Outlying-US(Guam-USVI-etc) 14
#  Peru 31
#  Philippines 198
#  Poland 60
#  Portugal 37
#  Puerto-Rico 114
#  Scotland 12
#  South 80
#  Taiwan 51
#  Thailand 18
#  Trinadad&Tobago 19
#  United-States 29169
#  Vietnam 67
#  Yugoslavia 16

# %%
plt.figure()
plt.bar(np.arange(len(feature_values)), feature_counts)
plt.xticks(np.arange(len(feature_values)),feature_values,rotation='vertical')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.pie(feature_counts,labels=feature_values)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
print(df.columns)
print(df.columns[3])
print(df.columns[9])
# Out:
# Index(['39', ' State-gov', ' 77516', ' Bachelors', ' 13', ' Never-married',
#        ' Adm-clerical', ' Not-in-family', ' White', ' Male', ' 2174', ' 0',
#        ' 40', ' United-States', ' <=50K'],
#       dtype='object')
#  Bachelors
#  Male

# %%
genero = df.values[:,9]
estudios = df.values[:,3]
print(np.unique(genero,return_counts=True))
# Out:
# (array([' Female', ' Male'], dtype=object), array([10771, 21789], dtype=int64))

# %%
f_et_estudios,f_fr_estudios = np.unique(estudios[genero==' Female'],return_counts=True)
print(f_et_estudios,f_fr_estudios)
m_et_estudios,m_fr_estudios = np.unique(estudios[genero==' Male'],return_counts=True)
print(m_et_estudios,m_fr_estudios)

plt.figure()
plt.subplot(1,2,1)
plt.title(' Female')
plt.pie(f_fr_estudios,labels=f_et_estudios)
plt.subplot(1,2,2)
plt.title(' Male')
plt.pie(m_fr_estudios,labels=m_et_estudios)
plt.show()
# Out:
# [' 10th' ' 11th' ' 12th' ' 1st-4th' ' 5th-6th' ' 7th-8th' ' 9th'
#  ' Assoc-acdm' ' Assoc-voc' ' Bachelors' ' Doctorate' ' HS-grad'
#  ' Masters' ' Preschool' ' Prof-school' ' Some-college'] [ 295  432  144   46   84  160  144  421  500 1619   86 3390  536   16
#    92 2806]
# [' 10th' ' 11th' ' 12th' ' 1st-4th' ' 5th-6th' ' 7th-8th' ' 9th'
#  ' Assoc-acdm' ' Assoc-voc' ' Bachelors' ' Doctorate' ' HS-grad'
#  ' Masters' ' Preschool' ' Prof-school' ' Some-college'] [ 638  743  289  122  249  486  370  646  882 3735  327 7111 1187   35
#   484 4485]
# <img src="data:image/png;base64,..." width="640">
